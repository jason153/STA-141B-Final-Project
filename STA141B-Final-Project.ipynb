# %% [markdown]
# ## STA 141B Final Project ##

# %%
import requests
from bs4 import BeautifulSoup as bs
import urllib.request
import csv
import json
import pandas as pd

# %%
# Data can be found here: https://www.zillow.com/research/data/
def parse():
    r = requests.get('https://www.zillow.com/research/data/') #download the webpage
    soup = bs(r.text) #create beautiful soup object 
    divs = soup.find_all(
        'div', {'class': ['form-group', 'select-wrapper', 'data-dropdown-2']}) #find all dividers with class of form-group, select-wrapper,data-dropdown-2
    vls = []
    for d in divs: #iterate through dividers
        try:
            ln = d.find('option') #look for the options 
            print(ln['value']) 
            vls.append(ln['value']) #append the option from our dividers 
        except:
            break
    return vls

parse()
vls = parse()

print(vls)
# Out:
# ZHVI All Homes (SFR, Condo/Co-op) Time Series, Smoothed, Seasonally Adjusted($)
# https://files.zillowstatic.com/research/public_csvs/zhvi/Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv?t=1638416437
# ZHVF (Forecast), All Homes (SFR, Condo/Co-op), Smoothed, Seasonally Adjusted, Mid-Tier (YoY%)
# https://files.zillowstatic.com/research/public_csvs/zhvf/zhvf_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv?t=1638416437
# ZORI (Smoothed, Seasonally Adjusted): All Homes Plus Multifamily Time Series ($)
# https://files.zillowstatic.com/research/public_csvs/zori/Metro_ZORI_AllHomesPlusMultifamily_SSA.csv?t=1638416437
# For-Sale Inventory (Smooth, All Homes, Monthly)
# https://files.zillowstatic.com/research/public_csvs/invt_fs/Metro_invt_fs_uc_sfrcondo_sm_month.csv?t=1638416437
# Median List Price (Smooth, All Homes, Monthly)
# https://files.zillowstatic.com/research/public_csvs/mlp/Metro_mlp_uc_sfrcondo_sm_month.csv?t=1638416437
# Sales Count Nowcast (Raw, All Homes)
# https://files.zillowstatic.com/research/public_csvs/sales_count_now/Metro_sales_count_now_uc_sfrcondo_month.csv?t=1638416437
# ZHVI All Homes (SFR, Condo/Co-op) Time Series, Smoothed, Seasonally Adjusted($)
# https://files.zillowstatic.com/research/public_csvs/zhvi/Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv?t=1638418358
# ZHVF (Forecast), All Homes (SFR, Condo/Co-op), Smoothed, Seasonally Adjusted, Mid-Tier (YoY%)
# https://files.zillowstatic.com/research/public_csvs/zhvf/zhvf_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv?t=1638418358
# ZORI (Smoothed, Seasonally Adjusted): All Homes Plus Multifamily Time Series ($)
# https://files.zillowstatic.com/research/public_csvs/zori/Metro_ZORI_AllHomesPlusMultifamily_SSA.csv?t=1638418358
# For-Sale Inventory (Smooth, All Homes, Monthly)
# https://files.zillowstatic.com/research/public_csvs/invt_fs/Metro_invt_fs_uc_sfrcondo_sm_month.csv?t=1638418358
# Median List Price (Smooth, All Homes, Monthly)
# https://files.zillowstatic.com/research/public_csvs/mlp/Metro_mlp_uc_sfrcondo_sm_month.csv?t=1638418358
# Sales Count Nowcast (Raw, All Homes)
# https://files.zillowstatic.com/research/public_csvs/sales_count_now/Metro_sales_count_now_uc_sfrcondo_month.csv?t=1638418358
# ['ZHVI All Homes (SFR, Condo/Co-op) Time Series, Smoothed, Seasonally Adjusted($)', 'https://files.zillowstatic.com/research/public_csvs/zhvi/Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv?t=1638418358', 'ZHVF (Forecast), All Homes (SFR, Condo/Co-op), Smoothed, Seasonally Adjusted, Mid-Tier (YoY%)', 'https://files.zillowstatic.com/research/public_csvs/zhvf/zhvf_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv?t=1638418358', 'ZORI (Smoothed, Seasonally Adjusted): All Homes Plus Multifamily Time Series ($)', 'https://files.zillowstatic.com/research/public_csvs/zori/Metro_ZORI_AllHomesPlusMultifamily_SSA.csv?t=1638418358', 'For-Sale Inventory (Smooth, All Homes, Monthly)', 'https://files.zillowstatic.com/research/public_csvs/invt_fs/Metro_invt_fs_uc_sfrcondo_sm_month.csv?t=1638418358', 'Median List Price (Smooth, All Homes, Monthly)', 'https://files.zillowstatic.com/research/public_csvs/mlp/Metro_mlp_uc_sfrcondo_sm_month.csv?t=1638418358', 'Sales Count Nowcast (Raw, All Homes)', 'https://files.zillowstatic.com/research/public_csvs/sales_count_now/Metro_sales_count_now_uc_sfrcondo_month.csv?t=1638418358']

# %%
# Gives us the ZHVI values over time It reflects the typical value for homes in the 35th to 65th percentile range.
# Uses this CSV: https://files.zillowstatic.com/research/public_csvs/zhvi/Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv?t=1637624134
def zhvi():
    url = vls[1]
    df = pd.read_csv(url)
    count = len(df.columns)
    return df

zhvi()
# Out:
#      RegionID  SizeRank                          RegionName RegionType  \
# 0      102001         0                       United States    Country
# 1      394913         1                        New York, NY        Msa
# 2      753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3      394463         3                         Chicago, IL        Msa
# 4      394514         4               Dallas-Fort Worth, TX        Msa
# ..        ...       ...                                 ...        ...
# 903    394767       929                          Lamesa, TX        Msa
# 904    753874       930                           Craig, CO        Msa
# 905    394968       931                           Pecos, TX        Msa
# 906    395188       932                          Vernon, TX        Msa
# 907    394743       933                       Ketchikan, AK        Msa
#
#     StateName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  \
# 0         NaN    127202.0    127546.0    127908.0    128645.0    129389.0
# 1          NY    224341.0    225681.0    226887.0    229261.0    231472.0
# 2          CA    231193.0    231998.0    233231.0    235576.0    238089.0
# 3          IL    170104.0    170505.0    171024.0    172064.0    173166.0
# 4          TX    130035.0    130139.0    130225.0    130437.0    130658.0
# ..        ...         ...         ...         ...         ...         ...
# 903        TX         NaN         NaN         NaN         NaN         NaN
# 904        CO     94741.0     95085.0     95668.0     96360.0     97075.0
# 905        TX         NaN         NaN         NaN         NaN         NaN
# 906        TX         NaN         NaN         NaN         NaN         NaN
# 907        AK         NaN         NaN         NaN         NaN         NaN
#
#      ...  2021-01-31  2021-02-28  2021-03-31  2021-04-30  2021-05-31  \
# 0    ...    271623.0    274979.0    278635.0    282495.0    287202.0
# 1    ...    516687.0    521426.0    525792.0    530533.0    536044.0
# 2    ...    741209.0    748698.0    756569.0    767615.0    783282.0
# 3    ...    258211.0    260534.0    262648.0    265690.0    268442.0
# 4    ...    276637.0    280005.0    284015.0    289524.0    295921.0
# ..   ...         ...         ...         ...         ...         ...
# 903  ...     81702.0     82847.0     84199.0     84499.0     84998.0
# 904  ...         NaN    214132.0    219224.0    223021.0    226345.0
# 905  ...    136993.0    139388.0    141606.0    143469.0    145612.0
# 906  ...         NaN     70218.0     71261.0     71623.0     72008.0
# 907  ...    321416.0    322965.0    325062.0    327187.0    329357.0
#
#      2021-06-30  2021-07-31  2021-08-31  2021-09-30  2021-10-31
# 0      292730.0    298613.0    304008.0    308632.0    312728.0
# 1      543211.0    551142.0    558738.0    564641.0    569191.0
# 2      803090.0    823992.0    837437.0    846549.0    851308.0
# 3      272263.0    276430.0    280547.0    283620.0    286280.0
# 4      303225.0    311010.0    318887.0    326057.0    332118.0
# ..          ...         ...         ...         ...         ...
# 903     85445.0     86421.0     87549.0     88609.0     89544.0
# 904    229787.0    232861.0    236543.0    239833.0    242809.0
# 905    147618.0    150033.0    155032.0    159714.0    164353.0
# 906     72666.0     73363.0     73961.0     74432.0     74762.0
# 907    330905.0    332472.0    334200.0    336433.0    338383.0
#
# [908 rows x 267 columns]

# %%
# Gives us the ZORI values over time which is computing the mean of listed rents that fall into the 40th to 60th percentile range for all homes and apartments in a given region
# Uses this CSV: https://files.zillowstatic.com/research/public_csvs/zori/Metro_ZORI_AllHomesPlusMultifamily_SSA.csv?t=1637624134
def zori():
    zori = vls[5]
    zoridf = pd.read_csv(zori)
    return zoridf

zori()
# Out:
#      RegionID                          RegionName  SizeRank  2014-01  2014-02  \
# 0      102001                       United States         0   1347.0     1352
# 1      394913                        New York, NY         1   2356.0     2366
# 2      753899  Los Angeles-Long Beach-Anaheim, CA         2   1719.0     1730
# 3      394463                         Chicago, IL         3   1374.0     1378
# 4      394514               Dallas-Fort Worth, TX         4   1125.0     1129
# ..        ...                                 ...       ...      ...      ...
# 100    394549                          Durham, NC       104   1102.0     1105
# 101    394995                  Port St. Lucie, FL       119   1057.0     1065
# 102    394602                    Fort Collins, CO       159   1213.0     1219
# 103    394405                         Boulder, CO       162   1502.0     1509
# 104    394623                     Gainesville, GA       229    940.0      943
#
#      2014-03  2014-04  2014-05  2014-06  2014-07  ...  2021-01  2021-02  \
# 0     1358.0     1364     1369     1375     1380  ...     1727     1744
# 1     2376.0     2387     2397     2408     2418  ...     2592     2608
# 2     1740.0     1750     1761     1771     1782  ...     2347     2366
# 3     1381.0     1385     1388     1392     1395  ...     1583     1591
# 4     1132.0     1136     1139     1143     1147  ...     1480     1498
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 100   1109.0     1112     1116     1119     1123  ...     1393     1407
# 101   1073.0     1081     1089     1097     1104  ...     1703     1732
# 102   1226.0     1233     1239     1246     1253  ...     1581     1594
# 103   1517.0     1524     1532     1540     1548  ...     2006     2022
# 104    945.0      947      950      953      956  ...     1392     1416
#
#      2021-03  2021-04  2021-05  2021-06  2021-07  2021-08  2021-09  2021-10
# 0       1761     1777   1795.0     1813     1830     1849   1867.0   1886.0
# 1       2624     2640   2658.0     2676     2694     2715   2736.0   2757.0
# 2       2384     2402   2421.0     2440     2459     2480   2500.0   2521.0
# 3       1599     1607   1615.0     1624     1633     1642   1652.0   1661.0
# 4       1516     1534   1552.0     1571     1589     1608   1628.0   1647.0
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 100     1420     1434   1448.0     1462     1476     1491   1506.0   1520.0
# 101     1760     1789   1818.0     1848     1877     1907   1938.0   1968.0
# 102     1608     1621   1634.0     1648     1662     1676   1690.0   1704.0
# 103     2038     2054   2070.0     2087     2103     2119   2136.0   2152.0
# 104     1439     1463      NaN     1511     1535     1560   1585.0   1610.0
#
# [105 rows x 97 columns]

# %%
# Gives us the median list price over time 
# Uses this CSV: https://files.zillowstatic.com/research/public_csvs/mlp/Metro_mlp_uc_sfrcondo_sm_month.csv?t=1637624134
def median():
    median = vls[9]
    mediandf = pd.read_csv(median)
    return mediandf

median()
# Out:
#     RegionID  SizeRank                          RegionName RegionType  \
# 0     102001         0                       United States    Country
# 1     394913         1                        New York, NY        Msa
# 2     753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3     394463         3                         Chicago, IL        Msa
# 4     394514         4               Dallas-Fort Worth, TX        Msa
# ..       ...       ...                                 ...        ...
# 90    394528        90                   Daytona Beach, FL        Msa
# 91    394531        91                      Des Moines, IA        Msa
# 92    395006       100                           Provo, UT        Msa
# 93    394549       104                          Durham, NC        Msa
# 94    394602       159                    Fort Collins, CO        Msa
#
#    StateName  2018-01-31  2018-02-28  2018-03-31  2018-04-30  2018-05-31  ...  \
# 0        NaN    271600.0    272967.0    279333.0    288667.0    295633.0  ...
# 1         NY    517967.0    523000.0    534333.0    544667.0    554666.0  ...
# 2         CA    798333.0    802667.0    818000.0    835000.0    848300.0  ...
# 3         IL    301000.0    305967.0    319300.0    335967.0    345967.0  ...
# 4         TX    341996.0    345330.0    351663.0    359830.0    366163.0  ...
# ..       ...         ...         ...         ...         ...         ...  ...
# 90        FL    269600.0    270300.0    271833.0    274833.0    279667.0  ...
# 91        IA    281600.0    285967.0    292293.0    297293.0    299593.0  ...
# 92        UT    389707.0    397680.0    408503.0    413706.0    409865.0  ...
# 93        NC    362699.0    367241.0    375112.0    382984.0    386785.0  ...
# 94        CO    442736.0    445785.0    448272.0    450000.0    454094.0  ...
#
#     2021-01-31  2021-02-28  2021-03-31  2021-04-30  2021-05-31  2021-06-30  \
# 0     333533.0    333850.0    340362.0    353728.0    367045.0    378267.0
# 1     661666.0    668000.0    673000.0    675000.0    675000.0    666667.0
# 2     996997.0    998698.0   1005698.0   1006364.0   1006666.0    999666.0
# 3     331333.0    331667.0    338300.0    346633.0    352967.0    354667.0
# 4     350726.0    352141.0    357025.0    365358.0    374884.0    383333.0
# ..         ...         ...         ...         ...         ...         ...
# 90    293410.0    297110.0    303500.0    314467.0    324467.0    336078.0
# 91    273633.0    277767.0    283300.0    291378.0    301725.0    311707.0
# 92    511346.0    515076.0    510630.0    512444.0    520778.0    537478.0
# 93    427593.0    431818.0    442273.0    466005.0    485372.0    495967.0
# 94         NaN         NaN         NaN         NaN         NaN         NaN
#
#     2021-07-31  2021-08-31  2021-09-30  2021-10-31
# 0     381567.0    379933.0    376633.0    375000.0
# 1     658000.0    643200.0    636533.0    631867.0
# 2     991333.0    971333.0    946667.0    931633.0
# 3     354633.0    348267.0    339933.0    332967.0
# 4     390167.0    393500.0    396500.0    397667.0
# ..         ...         ...         ...         ...
# 90    341612.0    346278.0    348000.0    352967.0
# 91    319628.0    320032.0    317550.0    314217.0
# 92    546633.0    549967.0    548467.0    545533.0
# 93    487633.0    480160.0    476526.0    478160.0
# 94         NaN         NaN         NaN         NaN
#
# [95 rows x 51 columns]

# %%
# Gives us the Zillow Home Value Forecast (ZHVF) which is the one-year forecast of the Zillow Home Values Index (ZHVI)
def zhvf():
    url = vls[3]
    df = pd.read_csv(url)
    count = len(df.columns)
    return df

zhvf()
# Out:
#         Region     RegionName StateName                    CountyName  \
# 0      Country  United States       NaN                           NaN
# 1          Msa   Aberdeen, SD        SD                           NaN
# 2          Msa   Aberdeen, WA        WA                           NaN
# 3          Msa    Abilene, TX        TX                           NaN
# 4          Msa        Ada, OK        OK                           NaN
# ...        ...            ...       ...                           ...
# 23462      Zip          99712        AK  Fairbanks North Star Borough
# 23463      Zip          99714        AK  Fairbanks North Star Borough
# 23464      Zip          99801        AK                Juneau Borough
# 23465      Zip          99824        AK                Juneau Borough
# 23466      Zip          99901        AK     Ketchikan Gateway Borough
#
#         CityName ForecastedDate  ForecastYoYPctChange
# 0            NaN     2022-10-31                  13.6
# 1            NaN     2022-10-31                   8.0
# 2            NaN     2022-10-31                  20.1
# 3            NaN     2022-10-31                  11.6
# 4            NaN     2022-10-31                  12.3
# ...          ...            ...                   ...
# 23462  Fairbanks     2022-10-31                   8.9
# 23463     Salcha     2022-10-31                   5.4
# 23464     Juneau     2022-10-31                   8.2
# 23465     Juneau     2022-10-31                   8.6
# 23466  Ketchikan     2022-10-31                   9.0
#
# [23467 rows x 7 columns]

# %%
# Gives us for sale inventory which is the count of unique listings that were active at any time in a given month.
def fsi():
    url = vls[7]
    df = pd.read_csv(url)
    count = len(df.columns)
    return df

fsi()
# Out:
#      RegionID  SizeRank                          RegionName RegionType  \
# 0      102001         0                       United States    Country
# 1      394913         1                        New York, NY        Msa
# 2      753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3      394463         3                         Chicago, IL        Msa
# 4      394514         4               Dallas-Fort Worth, TX        Msa
# ..        ...       ...                                 ...        ...
# 912    394767       929                          Lamesa, TX        Msa
# 913    753874       930                           Craig, CO        Msa
# 914    394968       931                           Pecos, TX        Msa
# 915    395188       932                          Vernon, TX        Msa
# 916    394743       933                       Ketchikan, AK        Msa
#
#     StateName  2018-01-31  2018-02-28  2018-03-31  2018-04-30  2018-05-31  \
# 0         NaN   1427909.0   1385346.0   1442557.0   1529778.0   1631645.0
# 1          NY     68934.0     68508.0     73030.0     79963.0     85976.0
# 2          CA     20081.0     19915.0     21870.0     23791.0     25757.0
# 3          IL     42815.0     41139.0     44766.0     49325.0     53872.0
# 4          TX     24283.0     23206.0     24346.0     26749.0     29536.0
# ..        ...         ...         ...         ...         ...         ...
# 912        TX        28.0        32.0        35.0        36.0        37.0
# 913        CO       120.0       112.0       110.0       112.0       121.0
# 914        TX        13.0        14.0        15.0        14.0        15.0
# 915        TX        19.0        20.0        21.0        27.0        32.0
# 916        AK        63.0        56.0        54.0        54.0        56.0
#
#      ...  2021-01-31  2021-02-28  2021-03-31  2021-04-30  2021-05-31  \
# 0    ...   1053828.0    974066.0    962689.0    944961.0    980620.0
# 1    ...     63693.0     59401.0     58657.0     59266.0     61377.0
# 2    ...     20646.0     19414.0     19913.0     20251.0     20694.0
# 3    ...     36968.0     33295.0     32883.0     33204.0     35630.0
# 4    ...     23662.0     21461.0     21041.0     20784.0     21797.0
# ..   ...         ...         ...         ...         ...         ...
# 912  ...        29.0        27.0        24.0        28.0        34.0
# 913  ...       105.0        89.0        81.0        80.0        77.0
# 914  ...        22.0        24.0        24.0        25.0        25.0
# 915  ...        17.0        15.0        13.0        13.0        13.0
# 916  ...        48.0        46.0        44.0        44.0        50.0
#
#      2021-06-30  2021-07-31  2021-08-31  2021-09-30  2021-10-31
# 0     1010612.0   1055726.0   1100059.0   1116567.0   1103788.0
# 1       63796.0     65300.0     65536.0     63953.0     62220.0
# 2       20787.0     21361.0     21805.0     21637.0     20776.0
# 3       37719.0     39713.0     41154.0     41284.0     40272.0
# 4       22541.0     23736.0     24760.0     24994.0     24094.0
# ..          ...         ...         ...         ...         ...
# 912        39.0        38.0        36.0        34.0        32.0
# 913        73.0        69.0        74.0        80.0        85.0
# 914        25.0        24.0        25.0        26.0        28.0
# 915        15.0        19.0        23.0        26.0        26.0
# 916        56.0        59.0        57.0        50.0        42.0
#
# [917 rows x 51 columns]

# %%
zhvi_df = zhvi()
nyc_zhvi_df = zhvi_df.iloc[:,5:][zhvi_df.RegionID == 394913]

nyc_zhvi_df.columns = pd.to_datetime(nyc_zhvi_df.columns)
nyc_zhvi_df.T.plot(legend = False, title = 'NYC ZHVI Over Time')
# Out:
# <AxesSubplot:title={'center':'NYC ZHVI Over Time'}>

# %%
zhvi_df = zhvi()
boulder_zhvi_df = zhvi_df.iloc[:,5:][zhvi_df.RegionID == 394405]

boulder_zhvi_df.columns = pd.to_datetime(boulder_zhvi_df.columns)
boulder_zhvi_df.T.plot(legend = False, title = 'Boulder ZHVI Over Time')
# Out:
# <AxesSubplot:title={'center':'Boulder ZHVI Over Time'}>
